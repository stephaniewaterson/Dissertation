# %%
#!pip install shapely==1.7.1

import shapely                 #needed to set geopandas geometry 
from shapely.wkt import loads  #needed to set geopandas geometry

import pandas as pd            #for DataFrame and analysis
import geopandas as gpd        #for mapping and spatial aggregation
import mapclassify as mp   #to view quantitative classification summaries

import matplotlib.pyplot as plt  #use matplotlib to modify the plots (e.g. make them larger) 

import palettable.colorbrewer.sequential as pcs  #for colorBrewer palettes

# %%
df = pd.read_csv("seagrass.csv")

# %%
df.head()
# Out:
#    OBJECTID Additional_information           WB_Name        Bed_Name  \
# 0       106                    NaN    Plymouth Sound   Battery Brake
# 1       107                    NaN             Yealm  Red Cove North
# 2       108                    NaN  Dorset/Hampshire        Studland
# 3       109                    NaN    Plymouth Tamar   Firestone Bay
# 4       110                    NaN    Plymouth Sound     Cawsand Bay
#
#      Area_Ha                Density   Habitat  Year_  \
# 0   0.667069  >5%, mean density 14%  Subtidal   2018
# 1   0.697299  >5%, mean density 59%  Subtidal   2018
# 2  77.915839  >5%, mean density 71%  Subtidal   2018
# 3   0.312429  >5%, mean density 17%  Subtidal   2018
# 4  17.923061  >5%, mean density 59%  Subtidal   2018
#
#                          Status Data_confidence  ...  \
# 0                   Most Recent            High  ...
# 1                   Most Recent            High  ...
# 2  Largest Extent & Most Recent            High  ...
# ...

# %%
gdf = gpd.read_file('geo.geojson')
gdf.to_file('geo.shp')
# Out:
# /opt/anaconda3/envs/sds2022/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /var/folders/jb/nrfg9k8s6059zjcm7knb8kr40000gn/T/ipykernel_27114/2702360511.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file('geo.shp')

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
pip install geojsonio==0.0.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
gdf.head()
# Out:
#    OBJECTID Additional_information           WB_Name        Bed_Name  \
# 0       106                   None    Plymouth Sound   Battery Brake
# 1       107                   None             Yealm  Red Cove North
# 2       108                   None  Dorset/Hampshire        Studland
# 3       109                   None    Plymouth Tamar   Firestone Bay
# 4       110                   None    Plymouth Sound     Cawsand Bay
#
#              Area_Ha                Density   Habitat Year_  \
# 0  0.667069214837805  >5%, mean density 14%  Subtidal  2018
# 1  0.697298911407986  >5%, mean density 59%  Subtidal  2018
# 2    77.915839263022  >5%, mean density 71%  Subtidal  2018
# 3  0.312428532923662  >5%, mean density 17%  Subtidal  2018
# 4   17.9230608965423  >5%, mean density 59%  Subtidal  2018
#
#                          Status Data_confidence  ...  \
# 0                   Most Recent            High  ...
# 1                   Most Recent            High  ...
# ...

# %%
gdf.columns
# Out:
# Index(['OBJECTID', 'Additional_information', 'WB_Name', 'Bed_Name', 'Area_Ha',
#        'Density', 'Habitat', 'Year_', 'Status', 'Data_confidence', 'HAB_TYPE',
#        'DET_MTHD', 'DET_NAME', 'DET_DATE', 'TRAN_COM', 'Dataset_UID',
#        'Source_dataset', 'Survey_Typ', 'Current_extent', 'ORIG_HAB',
#        'ORIG_CLASS', 'VERSION', 'T_RELATE', 'VAL_COMM',
#        'MESH_confidence_score', 'geometry'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['OBJECTID', 'Additional_information', 'WB_Name', 'Bed_Name', 'Area_Ha',
#        'Density', 'Habitat', 'Year_', 'Status', 'Data_confidence', 'HAB_TYPE',
#        'DET_MTHD', 'DET_NAME', 'DET_DATE', 'TRAN_COM', 'Dataset_UID',
#        'Source_dataset', 'Survey_Typ', 'Current_extent', 'ORIG_HAB',
#        'ORIG_CLASS', 'VERSION', 'T_RELATE', 'VAL_COMM',
#        'MESH_confidence_score', 'Shape__Area', 'Shape__Length'],
#       dtype='object')

# %%
pip install shapely
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge cartopy
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geoplot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geoplot.crs as gcrs

# %%
import numpy as np
import geojson
from descartes import PolygonPatch
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
plt.clf()
ax = plt.figure(figsize=(10,10)).add_subplot(111)#fig.gca()
 
m = Basemap(projection='robin', lon_0=0,resolution='c')
m.drawmapboundary(fill_color='white', zorder=-1)
m.drawparallels(np.arange(-90.,91.,30.), labels=[1,0,0,1], dashes=[1,1], linewidth=0.25, color='0.5',fontsize=14)
m.drawmeridians(np.arange(0., 360., 60.), labels=[1,0,0,1], dashes=[1,1], linewidth=0.25, color='0.5',fontsize=14)
m.drawcoastlines(color='0.6', linewidth=1)

# %%
uk = gpd.read_file("UK.geojson")

# %%
uk.to_file('uk.shp')
# Out:
# /opt/anaconda3/envs/sds2022/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /var/folders/jb/nrfg9k8s6059zjcm7knb8kr40000gn/T/ipykernel_27114/3242674696.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   uk.to_file('uk.shp')

# %%
uk.plot(figsize=(10,10))
# Out:
# <AxesSubplot: >

# %%
lgnd_kwds = {'title': 'Density', 'loc': 'upper left',
             'bbox_to_anchor': (1, 1.03), 'ncol':1}


gdf.plot(column='Density', cmap='summer', legend=True, legend_kwds=lgnd_kwds);
plt.xlabel('Latitude');
plt.ylabel('Longitude');
plt.title('`density seagrass');

# %%
print(uk.crs)
# Out:
# epsg:4326

# %%
print(gdf.crs)
# Out:
# epsg:27700

# %%
uk_proj = uk.to_crs({'init': 'epsg:27700'})
# Out:
# /opt/anaconda3/envs/sds2022/lib/python3.9/site-packages/pyproj/crs/crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
print(uk_proj.crs)
# Out:
# +init=epsg:27700 +type=crs

# %%
uk_proj.plot()
# Out:
# <AxesSubplot: >

# %%
import matplotlib.patches as mpatches
from matplotlib.legend_handler import HandlerPatch
import matplotlib.cm
from pylab import *
import numpy as np
from matplotlib import colors
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import cm

fig,ax1=plt.subplots(1, figsize=(15, 12))
ax1.set_title('Seagrass known location UK ', fontsize=10)
gdf.plot(gdf.plot(column='Density', cmap='summer', legend=True, legend_kwds=lgnd_kwds, ax=ax1)
plt.xlabel('Latitude');
plt.ylabel('Longitude');
plt.title('`density seagrass')
uk_proj.plot(ax=ax1, facecolor='None', edgecolor='darkblue', linewidth=1.5)
red_patch = mpatches.Patch(color='darkblue', label='State Boundaries')
plt.legend(handles=[red_patch])


ax1.axis('off')
# Out:
#   Cell In [1], line 14
#     gdf.plot(gdf.plot(column='Density', cmap='summer', legend=True, legend_kwds=lgnd_kwds, ax=ax1);
#                                                                                                   ^
# SyntaxError: invalid syntax
